# %% [markdown]
# **A Structured Output Agent in LangChain (or other LLM frameworks) refers to an agent that produces responses in a specific structured format, such as JSON, dictionaries, or other structured data types. These agents are particularly useful when you want to ensure that your responses conform to a defined schema, making it easier to parse, validate, and utilize in downstream applications.**
#
# ##### Why Use a Structured Output Agent?
#
# - Controlled Responses: Ensures that the outputs follow a specific format, reducing ambiguity.
# - Data Validation: Useful when you want the model output to fit predefined structures, like for APIs or database entries.
# - Automation: Makes integration with systems like dashboards, ETL pipelines, or business workflows easier.

# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_core.tools import tool
from pydantic import BaseModel, Field
from langgraph.graph import MessagesState,StateGraph, END
from langgraph.prebuilt import ToolNode
from langchain_core.messages import HumanMessage

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embedding = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 8431.17it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
tavily_tool = TavilySearchResults()

# %%
@tool
def get_city_details(prompt):
    "Should do a web search to find the required city details"
    response = tavily_tool.invoke(prompt)
    return response

# %%
tools = [get_city_details]

# %%
model_with_tools = llm.bind_tools(tools)

# %% [markdown]
# #### The BaseModel class is a core component of Pydantic, which is used extensively in Python applications for data validation, type checking, and parsing. It's particularly useful when working with APIs, web frameworks like FastAPI, and other scenarios where you need to enforce data structure and ensure data integrity.
#
# **Here's an overview of the BaseModel class, along with some examples to demonstrate how you can use it effectively.**
#
# ####This code defines a Pydantic model called CityDetails using the BaseModel class. Let's break it down:
#
# - Explanation:
# -
# - Class Definition:
#
# - CityDetails inherits from BaseModel, making it a data validation model.
# - Fields with Type Annotations:
#
# - state_name: A string representing the state name of a city.
# - state_capital: A string representing the capital of that state.
# - country_name: A string representing the country name where the city is located.
# - country_capital: A string representing the capital of that country.
#
# **Field Descriptions:**
#
# - Each field uses Field() to provide a description that helps clarify what information each attribute represents.
#
# #### Purpose:
#
# - The model validates and structures data related to cities.
# - Useful for ensuring that any data related to cities has the correct structure before processing.
# - Helpful in APIs (like FastAPI) to generate self-documenting endpoints.

# %%
class CityDetails(BaseModel):
    """Respond to the user with this"""
    state_name: str = Field(description="State name of the city")
    state_capital: str = Field(description="State capital of the city")
    country_name: str = Field(description="Country name of the city")
    country_capital: str = Field(description="Country capital of the city")

# %%
# Inherit 'messages' key from MessagesState, which is a list of chat messages
class AgentState(MessagesState):
    # Final structured response from the agent
    final_response: CityDetails

# %%
model_with_structured_output = llm.with_structured_output(CityDetails)

# %%
def call_model(state: AgentState):
    print(f" this is 01 input from call model {state}")
    messages = state['messages']
    
    # Convert tuple messages to proper message objects
    if messages and isinstance(messages[0], tuple):
        from langchain_core.messages import HumanMessage, AIMessage
        converted = []
        for msg in messages:
            if isinstance(msg, tuple):
                role, content = msg
                if role == "human":
                    converted.append(HumanMessage(content=content))
                else:
                    converted.append(AIMessage(content=content))
            else:
                converted.append(msg)
        messages = converted
    
    response = model_with_tools.invoke(messages)
    print(f"this is 02 response from call model  {response}")
    # We return a list, because this will get added to the existing list
    return {"messages": [response]}

# %%
def should_continue(state: AgentState):
    messages = state["messages"]
    last_message = messages[-1]
    
    # If there is no function call, then we respond to the user
    if not last_message.tool_calls:
        return "respond"
    # Otherwise if there is, we continue with the tool
    else:
        return "continue"

# %%
def respond(state: AgentState):
    print(f"here is 03 state from respond {state}")
    response = model_with_structured_output.invoke([HumanMessage(content=state['messages'][-1].content)])
    print(f"this is 04 response from respond{response}")
    return {"final_response": response}

# %%
# Define a new graph
workflow = StateGraph(AgentState)

# Define the two nodes we will cycle between
workflow.add_node("llm", call_model)
workflow.add_node("tools", ToolNode(tools))
workflow.add_node("respond", respond)


# Set the entrypoint as `agent`
# This means that this node is the first one called
workflow.set_entry_point("llm")

# We now add a conditional edge
workflow.add_conditional_edges(
    "llm",
    
    should_continue,
    {
        "continue": "tools",
        "respond": "respond",
    },
)

workflow.add_edge("tools", "llm")
workflow.add_edge("respond", END)
graph = workflow.compile()

# %%
from IPython.display import Image, display
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
@tool
def get_city_details(prompt: str) -> str:
	"""Should do a web search to find the required city details."""
	if not prompt:
		return "No prompt provided for city lookup."
	return str(tavily_tool.invoke(prompt))

tools = [get_city_details]
model_with_tools = llm.bind_tools(tools)

# Rebuild graph so ToolNode picks up the updated tool schema
workflow = StateGraph(AgentState)
workflow.add_node("llm", call_model)
workflow.add_node("tools", ToolNode(tools))
workflow.add_node("respond", respond)
workflow.set_entry_point("llm")
workflow.add_conditional_edges(
	"llm",
	should_continue,
	{"continue": "tools", "respond": "respond"},
)
workflow.add_edge("tools", "llm")
workflow.add_edge("respond", END)
graph = workflow.compile()

answer = graph.invoke(
	input={"messages": [HumanMessage(content="Tell me about the city details for Gwalior?")]}
)["final_response"]
# Out:
#  this is 01 input from call model {'messages': [HumanMessage(content='Tell me about the city details for Gwalior?', additional_kwargs={}, response_metadata={}, id='7b931b5c-97da-4f76-9c51-a3443704b932')]}
# this is 02 response from call model  content='' additional_kwargs={'function_call': {'name': 'get_city_details', 'arguments': '{"prompt": "Gwalior"}'}, '__gemini_function_call_thought_signatures__': {'fb948718-d321-4a1d-810a-e3a3c8805c7b': '...'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019d357e-8dd7-7cf0-a019-2e5d712ba62b-0' tool_calls=[{'name': 'get_city_details', 'args': {'prompt': 'Gwalior'}, 'id': 'fb948718-d321-4a1d-810a-e3a3c8805c7b', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 58, 'output_tokens': 87, 'total_tokens': 145, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 68}}
#  this is 01 input from call model {'messages': [HumanMessage(content='Tell me about the city details for Gwalior?', additional_kwargs={}, response_metadata={}, id='7b931b5c-97da-4f76-9c51-a3443704b932'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_city_details', 'arguments': '{"prompt": "Gwalior"}'}, '__gemini_function_call_thought_signatures__': {'fb948718-d321-4a1d-810a-e3a3c8805c7b': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d357e-8dd7-7cf0-a019-2e5d712ba62b-0', tool_calls=[{'name': 'get_city_details', 'args': {'prompt': 'Gwalior'}, 'id': 'fb948718-d321-4a1d-810a-e3a3c8805c7b', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 58, 'output_tokens': 87, 'total_tokens': 145, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 68}}), ToolMessage(content='[{\'title\': \'Gwalior - Wikipedia\', \'url\': \'https://en.wikipedia.org/wiki/Gwalior\', \'content\': \'Gwalior (pronounced (/wiki/Help:IPA/Hindi_and_Urdu "Help:IPA/Hindi and Urdu") ⓘ) is a major city in the central Indian state of Madhya Pradesh. It is known as the Music City of India having the oldest musical gharana in existence. It is a major sports, cultural, industrial, and political centre in Madhya Pradesh. Gwalior is among the seven cities selected for new startup centres under India\\\'s growing innovation ecosystem. On World Cities Day (31 October 2023), UNESCO Director - General Audrey Azoulay announced Gwalior\\\'s inclusion among 55 new world creative cities in the UCCN from India. This tag elevates Gwalior\\\'s identity internationally, spotlighting its artists, music traditions and vibrant culture. It lies in the northern part of Madhya Pradesh and is one of the [...] Gwalior holds a major position in the Indian classical music, with being the birthplace of the oldest Hindustani sangeet gharana – Gwalior Gharana. Gwalior holds an unparalleled reputation in Sangeet "Sangeet (music)") and has retained Indian traditions and the wealth of music intact over the years. The Gwalior Gharana is not only the oldest Khyal Gharana but it is also one of the most prominent gharana being the one to which most classical Indian musicians can trace the origin of their style. The rise of the Gwalior Gharana started with the reign of the great Mughal emperor Akbar (1542–1605). Akbar\\\'s favourite singer was Tansen, who came from the Gwalior area and whose ashes were buried in Gwalior after his death. The Tansen Tomb in Gwalior was constructed in his remembrance. Tansen [...] The earliest historical record found at Gwalior is the Gwalior inscription of the Alchon Hun ruler Mihirakula. It describes Mihirakula\\\'s father Toramana (493–515) as "a ruler of the earth, of great merit, who was renowned by the name of the glorious Tôramâna; by whom, through (his) heroism that was specially characterized by truthfulness, the earth was governed with justice", and his Mihirakula as "the lord of the earth" as of 520 CE.\\n\\nAround the 9th century, the Gurjara-Pratihara dynasty controlled Gwalior and during their rule, they constructed the Teli ka Mandir temple. The Kachchhapaghata dynasty ruled the area c.950 –c.1192 CE, leaving remarkable architectural works such as the Sas and Bahu Temples. In 1021, Gwalior was attacked by forces led by Mahmud Ghazni.\', \'score\': 0.99998736}, {\'title\': \'Must-Visit Tourist Places in Gwalior (2026)\', \'url\': \'https://www.mptourism.com/destination-gwalior.php\', \'content\': "The history of Gwalior can be traced from the legend of eighth century AD, about a chieftain, Suraj Sen who contracted leprosy and was cured by the hermit-saint Gwalipa. He established this city in his honour as a mark of gratitude for the incident. Over the years, the newly established city, Gwalior came into existence. Gwalior has been the birthplace of many powerful dynasties. T ...
# this is 02 response from call model  content=[{'type': 'text', 'text': 'Gwalior is a major city in the central Indian state of Madhya Pradesh, known as the "Music City of India." It was recently included in the UNESCO Creative Cities Network for its rich musical heritage, being the birthplace of the oldest Hindustani sangeet gharana – Gwalior Gharana. The legendary Indian classical singer Tansen was from the Gwalior area and his ashes are buried there.\n\nHistorically, Gwalior has been ruled by various dynasties, including the Alchon Huns, Gurjara-Pratihara, Kachchhapaghata, and the Maratha Sindhia family.\n\nA prominent landmark is the Gwalior Fort, a 5th-century hill fort often referred to as the "Gibraltar of India." It has been added to the Tentative list of UNESCO World Heritage Sites. Other attractions include the Man Mandir Palace, the Tombs of Mohammed Ghaus & Tansen, and the Mahatma Gandhi Zoological Park. The Chaturbhuj Temple in Gwalior is notable for containing the world\'s first occurrence of zero as a written number.\n\nGwalior is also an important commercial and industrial center, recognized for its textiles, handlooms (like Chanderi and Maheshwari silks), and various manufactured goods. It is well-connected with a major national highway, a railway junction, and an airport.', 'extras': {'signature': '...'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019d357e-a7f4-7da0-97c9-e9767c23bf08-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 2865, 'output_tokens': 591, 'total_tokens': 3456, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 313}}
# here is 03 state from respond {'messages': [HumanMessage(content='Tell me about the city details for Gwalior?', additional_kwargs={}, response_metadata={}, id='7b931b5c-97da-4f76-9c51-a3443704b932'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_city_details', 'arguments': '{"prompt": "Gwalior"}'}, '__gemini_function_call_thought_signatures__': {'fb948718-d321-4a1d-810a-e3a3c8805c7b': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d357e-8dd7-7cf0-a019-2e5d712ba62b-0', tool_calls=[{'name': 'get_city_details', 'args': {'prompt': 'Gwalior'}, 'id': 'fb948718-d321-4a1d-810a-e3a3c8805c7b', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 58, 'output_tokens': 87, 'total_tokens': 145, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 68}}), ToolMessage(content='[{\'title\': \'Gwalior - Wikipedia\', \'url\': \'https://en.wikipedia.org/wiki/Gwalior\', \'content\': \'Gwalior (pronounced (/wiki/Help:IPA/Hindi_and_Urdu "Help:IPA/Hindi and Urdu") ⓘ) is a major city in the central Indian state of Madhya Pradesh. It is known as the Music City of India having the oldest musical gharana in existence. It is a major sports, cultural, industrial, and political centre in Madhya Pradesh. Gwalior is among the seven cities selected for new startup centres under India\\\'s growing innovation ecosystem. On World Cities Day (31 October 2023), UNESCO Director - General Audrey Azoulay announced Gwalior\\\'s inclusion among 55 new world creative cities in the UCCN from India. This tag elevates Gwalior\\\'s identity internationally, spotlighting its artists, music traditions and vibrant culture. It lies in the northern part of Madhya Pradesh and is one of the [...] Gwalior holds a major position in the Indian classical music, with being the birthplace of the oldest Hindustani sangeet gharana – Gwalior Gharana. Gwalior holds an unparalleled reputation in Sangeet "Sangeet (music)") and has retained Indian traditions and the wealth of music intact over the years. The Gwalior Gharana is not only the oldest Khyal Gharana but it is also one of the most prominent gharana being the one to which most classical Indian musicians can trace the origin of their style. The rise of the Gwalior Gharana started with the reign of the great Mughal emperor Akbar (1542–1605). Akbar\\\'s favourite singer was Tansen, who came from the Gwalior area and whose ashes were buried in Gwalior after his death. The Tansen Tomb in Gwalior was constructed in his remembrance. Tansen [...] The earliest historical record found at Gwalior is the Gwalior inscription of the Alchon Hun ruler Mihirakula. It describes Mihirakula\\\'s father Toramana (493–515) as "a ruler of the earth, of great merit, who was renowned by the name of the glorious Tôramâna; by whom, through (his) heroism that was specially characterized by truthfulness, the earth was governed with justice", and his Mihirakula as "the lord of the earth" as of 520 CE.\\n\\nAround the 9th century, the Gurjara-Pratihara dynasty controlled Gwalior and during their rule, they constructed the Teli ka Mandir temple. The Kachchhapaghata dynasty ruled the area c.950 –c.1192 CE, leaving remarkable architectural works such as the Sas and Bahu Temples. In 1021, Gwalior was attacked by forces led by Mahmud Ghazni.\', \'score\': 0.99998736}, {\'title\': \'Must-Visit Tourist Places in Gwalior (2026)\', \'url\': \'https://www.mptourism.com/destination-gwalior.php\', \'content\': "The history of Gwalior can be traced from the legend of eighth century AD, about a chieftain, Suraj Sen who contracted leprosy and was cured by the hermit-saint Gwalipa. He established this city in his honour as a mark of gratitude for the incident. Over the years, the newly established city, Gwalior came into existence. Gwalior has been the birthplace of many powerful dynasties. The c ...
# this is 04 response from respondstate_name='Madhya Pradesh' state_capital='Bhopal' country_name='India' country_capital='New Delhi'

# %%
answer = graph.invoke(
	input={"messages": [HumanMessage(content="Tell me about the city details for Gwalior?")]}
)["final_response"]
# Out:
#  this is 01 input from call model {'messages': [HumanMessage(content='Tell me about the city details for Gwalior?', additional_kwargs={}, response_metadata={}, id='21e35e38-2991-4f7b-b675-1fffcbc499ec')]}
# this is 02 response from call model  content='' additional_kwargs={'function_call': {'name': 'get_city_details', 'arguments': '{"prompt": "Gwalior"}'}, '__gemini_function_call_thought_signatures__': {'153232b7-33d7-42f3-ab75-87cf76684905': '...'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019d357f-9cbc-7133-acc8-1b12e6e5f36e-0' tool_calls=[{'name': 'get_city_details', 'args': {'prompt': 'Gwalior'}, 'id': '153232b7-33d7-42f3-ab75-87cf76684905', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 58, 'output_tokens': 86, 'total_tokens': 144, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 67}}
#  this is 01 input from call model {'messages': [HumanMessage(content='Tell me about the city details for Gwalior?', additional_kwargs={}, response_metadata={}, id='21e35e38-2991-4f7b-b675-1fffcbc499ec'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_city_details', 'arguments': '{"prompt": "Gwalior"}'}, '__gemini_function_call_thought_signatures__': {'153232b7-33d7-42f3-ab75-87cf76684905': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d357f-9cbc-7133-acc8-1b12e6e5f36e-0', tool_calls=[{'name': 'get_city_details', 'args': {'prompt': 'Gwalior'}, 'id': '153232b7-33d7-42f3-ab75-87cf76684905', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 58, 'output_tokens': 86, 'total_tokens': 144, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 67}}), ToolMessage(content='[{\'title\': \'Gwalior - Wikipedia\', \'url\': \'https://en.wikipedia.org/wiki/Gwalior\', \'content\': \'Gwalior (pronounced (/wiki/Help:IPA/Hindi_and_Urdu "Help:IPA/Hindi and Urdu") ⓘ) is a major city in the central Indian state of Madhya Pradesh. It is known as the Music City of India having the oldest musical gharana in existence. It is a major sports, cultural, industrial, and political centre in Madhya Pradesh. Gwalior is among the seven cities selected for new startup centres under India\\\'s growing innovation ecosystem. On World Cities Day (31 October 2023), UNESCO Director - General Audrey Azoulay announced Gwalior\\\'s inclusion among 55 new world creative cities in the UCCN from India. This tag elevates Gwalior\\\'s identity internationally, spotlighting its artists, music traditions and vibrant culture. It lies in the northern part of Madhya Pradesh and is one of the [...] Gwalior holds a major position in the Indian classical music, with being the birthplace of the oldest Hindustani sangeet gharana – Gwalior Gharana. Gwalior holds an unparalleled reputation in Sangeet "Sangeet (music)") and has retained Indian traditions and the wealth of music intact over the years. The Gwalior Gharana is not only the oldest Khyal Gharana but it is also one of the most prominent gharana being the one to which most classical Indian musicians can trace the origin of their style. The rise of the Gwalior Gharana started with the reign of the great Mughal emperor Akbar (1542–1605). Akbar\\\'s favourite singer was Tansen, who came from the Gwalior area and whose ashes were buried in Gwalior after his death. The Tansen Tomb in Gwalior was constructed in his remembrance. Tansen [...] The earliest historical record found at Gwalior is the Gwalior inscription of the Alchon Hun ruler Mihirakula. It describes Mihirakula\\\'s father Toramana (493–515) as "a ruler of the earth, of great merit, who was renowned by the name of the glorious Tôramâna; by whom, through (his) heroism that was specially characterized by truthfulness, the earth was governed with justice", and his Mihirakula as "the lord of the earth" as of 520 CE.\\n\\nAround the 9th century, the Gurjara-Pratihara dynasty controlled Gwalior and during their rule, they constructed the Teli ka Mandir temple. The Kachchhapaghata dynasty ruled the area c.950 –c.1192 CE, leaving remarkable architectural works such as the Sas and Bahu Temples. In 1021, Gwalior was attacked by forces led by Mahmud Ghazni.\', \'score\': 0.99998736}, {\'title\': \'Must-Visit Tourist Places in Gwalior (2026)\', \'url\': \'https://www.mptourism.com/destination-gwalior.php\', \'content\': "The history of Gwalior can be traced from the legend of eighth century AD, about a chieftain, Suraj Sen who contracted leprosy and was cured by the hermit-saint Gwalipa. He established this city in his honour as a mark of gratitude for the incident. Over the years, the newly established city, Gwalior came into existence. Gwalior has been the birthplace of many powerful dynasties. T ...
# this is 02 response from call model  content=[{'type': 'text', 'text': 'Gwalior is a major city in the central Indian state of Madhya Pradesh, renowned as the "Music City of India" and recognized by UNESCO as a Creative City of Music. Its rich musical heritage is highlighted by being the birthplace of the oldest Hindustani sangeet gharana – the Gwalior Gharana, and the resting place of the legendary singer Tansen.\n\nThe city has a long and storied history, with its origins tracing back to an 8th-century legend involving chieftain Suraj Sen and the hermit-saint Gwalipa. Gwalior has been ruled by various dynasties, including the Gurjara-Pratihara, Kachchhapaghata, Mughal, and Maratha (Sindhia family), all of whom left their mark on its culture and architecture.\n\nA prominent landmark is the majestic Gwalior Fort, often called the "Gibraltar of India." This 5th-century hill fort stands on a cliffed plateau and contains several palaces, temples (like the Teli ka Mandir and Sas Bahu Temples), and tanks. It has witnessed significant historical events and is considered one of India\'s most impregnable forts, even being added to the Tentative list of UNESCO World Heritage Sites.\n\nGwalior is also an important commercial and industrial center, known for textiles, handlooms (Chanderi and Maheshwari silks), carpets, and various other manufactured goods. Markets like Maharaj Bada, Sarafa Bazaar, and Topi Bazaar offer a diverse range of products, including traditional Batto Bai Dolls.\n\nOther notable attractions include the Tombs of Mohammed Ghaus and Tansen, the Man Mandir Palace, and the Mahatma Gandhi Zoological Park. The Chaturbhuj Temple in Gwalior also holds the world\'s first occurrence of zero as a written number.', 'extras': {'signature': '...'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019d357f-aca6-7f62-8399-dc7d44eb6dd8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 2865, 'output_tokens': 453, 'total_tokens': 3318, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 82}}
# here is 03 state from respond {'messages': [HumanMessage(content='Tell me about the city details for Gwalior?', additional_kwargs={}, response_metadata={}, id='21e35e38-2991-4f7b-b675-1fffcbc499ec'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_city_details', 'arguments': '{"prompt": "Gwalior"}'}, '__gemini_function_call_thought_signatures__': {'153232b7-33d7-42f3-ab75-87cf76684905': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d357f-9cbc-7133-acc8-1b12e6e5f36e-0', tool_calls=[{'name': 'get_city_details', 'args': {'prompt': 'Gwalior'}, 'id': '153232b7-33d7-42f3-ab75-87cf76684905', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 58, 'output_tokens': 86, 'total_tokens': 144, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 67}}), ToolMessage(content='[{\'title\': \'Gwalior - Wikipedia\', \'url\': \'https://en.wikipedia.org/wiki/Gwalior\', \'content\': \'Gwalior (pronounced (/wiki/Help:IPA/Hindi_and_Urdu "Help:IPA/Hindi and Urdu") ⓘ) is a major city in the central Indian state of Madhya Pradesh. It is known as the Music City of India having the oldest musical gharana in existence. It is a major sports, cultural, industrial, and political centre in Madhya Pradesh. Gwalior is among the seven cities selected for new startup centres under India\\\'s growing innovation ecosystem. On World Cities Day (31 October 2023), UNESCO Director - General Audrey Azoulay announced Gwalior\\\'s inclusion among 55 new world creative cities in the UCCN from India. This tag elevates Gwalior\\\'s identity internationally, spotlighting its artists, music traditions and vibrant culture. It lies in the northern part of Madhya Pradesh and is one of the [...] Gwalior holds a major position in the Indian classical music, with being the birthplace of the oldest Hindustani sangeet gharana – Gwalior Gharana. Gwalior holds an unparalleled reputation in Sangeet "Sangeet (music)") and has retained Indian traditions and the wealth of music intact over the years. The Gwalior Gharana is not only the oldest Khyal Gharana but it is also one of the most prominent gharana being the one to which most classical Indian musicians can trace the origin of their style. The rise of the Gwalior Gharana started with the reign of the great Mughal emperor Akbar (1542–1605). Akbar\\\'s favourite singer was Tansen, who came from the Gwalior area and whose ashes were buried in Gwalior after his death. The Tansen Tomb in Gwalior was constructed in his remembrance. Tansen [...] The earliest historical record found at Gwalior is the Gwalior inscription of the Alchon Hun ruler Mihirakula. It describes Mihirakula\\\'s father Toramana (493–515) as "a ruler of the earth, of great merit, who was renowned by the name of the glorious Tôramâna; by whom, through (his) heroism that was specially characterized by truthfulness, the earth was governed with justice", and his Mihirakula as "the lord of the earth" as of 520 CE.\\n\\nAround the 9th century, the Gurjara-Pratihara dynasty controlled Gwalior and during their rule, they constructed the Teli ka Mandir temple. The Kachchhapaghata dynasty ruled the area c.950 –c.1192 CE, leaving remarkable architectural works such as the Sas and Bahu Temples. In 1021, Gwalior was attacked by forces led by Mahmud Ghazni.\', \'score\': 0.99998736}, {\'title\': \'Must-Visit Tourist Places in Gwalior (2026)\', \'url\': \'https://www.mptourism.com/destination-gwalior.php\', \'content\': "The history of Gwalior can be traced from the legend of eighth century AD, about a chieftain, Suraj Sen who contracted leprosy and was cured by the hermit-saint Gwalipa. He established this city in his honour as a mark of gratitude for the incident. Over the years, the newly established city, Gwalior came into existence. Gwalior has been the birthplace of many powerful dynasties. The c ...
# this is 04 response from respondstate_name='Madhya Pradesh' state_capital='Bhopal' country_name='India' country_capital='New Delhi'

# %%
answer
# Out:
# CityDetails(state_name='Madhya Pradesh', state_capital='Bhopal', country_name='India', country_capital='New Delhi')
